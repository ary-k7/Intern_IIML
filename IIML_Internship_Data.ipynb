# %%
import datetime
from datetime import date
import pandas as pd
df = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy.xlsx', sheet_name='Sheet1')
type(df.start[0].day)
# Out:
# int

# %%
from nsepy import get_history
from datetime import date
data = get_history(symbol="RELIANCE", start=date(2017,1,1), end=date(2020,2,29))
data.to_excel('RelianceSpot1.xlsx')

# %%
from nsepy import get_history
from datetime import date
data = get_history(symbol="BANKNIFTY", start=date(2017,1,1), end=date(2020,2,29), index= True)
data.to_excel('BankNiftySpot.xlsx')

# %%
B=df()
type(B)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-cc157a044afc> in <module>
# ----> 1 B=df()
#       2 type(B)
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame
B=[]
df = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy.xlsx', sheet_name='Sheet1')
script = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy (2).xlsx', sheet_name='Sheet1')
K=pd.DataFrame()
for j in range (0,159):
    for i in range (0,38):
            A = get_history(symbol= (script.loc[j]),
                    start=date(df.start[i].year, df.start[i].month, df.start[i].day), 
                    end=date(df.end[i].year, df.end[i].month, df.end[i].day),
                    futures = True,
                    expiry_date=date(df.expiry[i].year, df.expiry[i].month, df.expiry[i].day))
            K=K.append(A)
print(K)
# Out:
#            Symbol      Expiry     Open     High      Low    Close     Last  \
# Date
# 2017-01-02    ACC  2017-01-25  1341.00  1360.60  1335.15  1357.90  1359.50
# 2017-01-03    ACC  2017-01-25  1361.05  1361.05  1341.50  1345.25  1343.05
# 2017-01-04    ACC  2017-01-25  1344.40  1353.60  1320.85  1324.90  1324.50
# 2017-01-05    ACC  2017-01-25  1329.80  1341.80  1326.70  1337.35  1337.50
# 2017-01-06    ACC  2017-01-25  1337.50  1353.90  1335.05  1338.45  1336.00
# 2017-01-09    ACC  2017-01-25  1350.00  1350.00  1321.10  1330.65  1328.05
# 2017-01-10    ACC  2017-01-25  1333.00  1334.95  1317.40  1324.15  1325.90
# 2017-01-11    ACC  2017-01-25  1328.00  1358.50  1325.05  1354.75  1354.75
# 2017-01-12    ACC  2017-01-25  1359.95  1364.20  1337.25  1345.95  1346.00
# 2017-01-13    ACC  2017-01-25  1344.70  1348.45  1330.75  1333.30  1334.50
# 2017-01-16    ACC  2017-01-25  1333.20  1342.95  1327.70  1335.60  1334.00
# ...

# %%
K.to_excel('iimlfinal1.xlsx')

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame
stock_opt = get_history(symbol="RELIANCE",
                        start=date(2020,1,31),
                        end=date(2020,2,27),
                        option_type="CE",
                        strike_price=1400,
                        expiry_date=date(2020,2,27))
(stock_opt)
# Out:
#               Symbol      Expiry Option Type  Strike Price    Open    High  \
# Date
# 2020-01-31  RELIANCE  2020-02-27          CE        1400.0   73.10   77.50
# 2020-02-01  RELIANCE  2020-02-27          CE        1400.0   55.20   64.45
# 2020-02-03  RELIANCE  2020-02-27          CE        1400.0   32.55   38.05
# 2020-02-04  RELIANCE  2020-02-27          CE        1400.0   37.75   52.60
# 2020-02-05  RELIANCE  2020-02-27          CE        1400.0   52.85   66.00
# 2020-02-06  RELIANCE  2020-02-27          CE        1400.0   66.50   75.00
# 2020-02-07  RELIANCE  2020-02-27          CE        1400.0   64.10   64.10
# 2020-02-10  RELIANCE  2020-02-27          CE        1400.0   50.25   57.00
# 2020-02-11  RELIANCE  2020-02-27          CE        1400.0   66.95   73.50
# 2020-02-12  RELIANCE  2020-02-27          CE        1400.0   68.00   79.30
# 2020-02-13  RELIANCE  2020-02-27          CE        1400.0   76.00   80.20
# ...

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame

df = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy.xlsx', sheet_name='Sheet1')
K=pd.DataFrame()
for i in range (0,38):
    for j in range (6,18):
        A = get_history(symbol= "RELIANCE",
                        start=date(df.start[i].year, df.start[i].month, df.start[i].day),
                        end=date(df.end[i].year, df.end[i].month, df.end[i].day),
                        option_type="CE",
                        strike_price=(100*j),
                        expiry_date=date(df.expiry[i].year, df.expiry[i].month, df.expiry[i].day))
        K=K.append(A)
print(K)
K.to_excel('RELIANCEOPT_FINAL.xlsx')
# Out:
#               Symbol      Expiry Option Type  Strike Price  Open  High   Low  \
# Date
# 2017-01-02  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-03  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-04  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-05  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-06  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-09  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-10  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-11  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-12  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-13  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# 2017-01-16  RELIANCE  2017-01-25          CE         800.0  0.00  0.00  0.00
# ...

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame

df = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy.xlsx', sheet_name='Sheet1')
for i in range (37,38):
    print(df.start[i].year, df.start[i].month, df.start[i].day)
    print(df.expiry[i].year, df.expiry[i].month, df.expiry[i].day)
# Out:
# 2020 1 31
# 2020 2 27

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame

df = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy.xlsx', sheet_name='Sheet1')
K=pd.DataFrame()
for i in range (0,38):
    for j in range (5,17):
        A = get_history(symbol= "RELIANCE",
                        start=date(df.start[i].year, df.start[i].month, df.start[i].day),
                        end=date(df.end[i].year, df.end[i].month, df.end[i].day),
                        option_type="PE",
                        strike_price=(100*j),
                        expiry_date=date(df.expiry[i].year, df.expiry[i].month, df.expiry[i].day))
        K=K.append(A)
print(K)
K.to_excel('RELIANCEOPT_PE_FINAL.xlsx')
# Out:
#               Symbol      Expiry Option Type  Strike Price    Open    High  \
# Date
# 2017-01-02  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-03  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-04  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-05  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-06  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-09  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-10  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-11  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-12  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-13  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# 2017-01-16  RELIANCE  2017-01-25          PE         800.0    0.00    0.00
# ...

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame

vix = get_history(symbol="INDIAVIX",
            start=date(2020,2,28),
            end=date(2021,6,24),
            index=True)
vix.to_excel('INDIAVIX_FINAL123.xlsx')

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame

nifty_opt = get_history(symbol="NIFTY",
                        start=date(2015,1,1),
                        end=date(2015,1,10),
                        index=True,
                        option_type='CE',
                        strike_price=8200,
                        expiry_date=date(2015,1,29))

# %%
import pandas as pd
from datetime import date
from nsepy import get_history
from pandas import DataFrame

df = pd.read_excel(r'C:\Users\Hp\Desktop\iiml - Copy.xlsx', sheet_name='Sheet1')
K=pd.DataFrame()
for i in range (0,38):
    for j in range (75,125):
        A = get_history(symbol= "NIFTY",
                        start=date(df.start[i].year, df.start[i].month, df.start[i].day),
                        end=date(df.end[i].year, df.end[i].month, df.end[i].day),
                        index=True,
                        option_type="CE",
                        strike_price=(100*j),
                        expiry_date=date(df.expiry[i].year, df.expiry[i].month, df.expiry[i].day))
        K=K.append(A)
print(K)
K.to_excel('NIFTY_OPT_FINAL.xlsx')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...
